# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Age": [22, 25, 27, 30, 35, 40, 120, 28, 26, 29]  # 120 is outlier
}

df = pd.DataFrame(data)

# %%
df
# Out:
#    Age
# 0   22
# 1   25
# 2   27
# 3   30
# 4   35
# 5   40
# 6  120
# 7   28
# 8   26
# 9   29

# %%
df['Age'].describe()
# Out:
# count     10.00000
# mean      38.20000
# std       29.19589
# min       22.00000
# 25%       26.25000
# 50%       28.50000
# 75%       33.75000
# max      120.00000
# Name: Age, dtype: float64

# %%
plt.boxplot(df["Age"])
plt.title("Outlier Detection")
plt.show()

# %%
#To Find IQR

Q1 = df["Age"].quantile(0.25)
Q3 = df["Age"].quantile(0.75)

IQR = Q3 - Q1

print("Q1:", Q1)


print("Q3:", Q3)
print("IQR:", IQR)
# Out:
# Q1: 26.25
# Q3: 33.75
# IQR: 7.5

# %%
#To Find Lower Bound And Upper Bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
# Out:
# Lower Bound: 15.0
# Upper Bound: 45.0

# %%
#To Find Outlier detect
outliers = df[(df["Age"] < lower_bound) | (df["Age"] > upper_bound)]

# %%
outliers
# Out:
#    Age
# 6  120

# %%
#To Remove Outlier

df_clean = df[(df["Age"] >= lower_bound) & (df["Age"] <= upper_bound)]

# %%
df_clean
# Out:
#    Age
# 0   22
# 1   25
# 2   27
# 3   30
# 4   35
# 5   40
# 7   28
# 8   26
# 9   29
