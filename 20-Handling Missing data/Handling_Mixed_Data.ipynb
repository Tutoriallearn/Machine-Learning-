# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/home/messy_ecommerce_sales_data.csv')
df.columns = df.columns.str.strip().str.replace(' ', '_')
df = df[['Customer_Name','Order_ID']]

# %%
df.head()
# Out:
#   Customer_Name   Order_ID
# 0  Customer_100  ORD-41285
# 1  Customer_101  ORD-35783
# 2  Customer_102  ORD-84355
# 3  Customer_103  ORD-57811
# 4  Customer_104  ORD-93614
