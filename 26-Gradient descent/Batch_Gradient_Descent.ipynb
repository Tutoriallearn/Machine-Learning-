# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Dataset
X = np.array([1, 2, 3, 4], dtype=float)
Y = np.array([2, 4, 6, 8], dtype=float)

# %%
# Initialize parameters
m = 0
b = 0

# %%
# Hyperparameters
learning_rate = 0.01
epochs = 1000

n = len(X)

# %%
# Batch Gradient Descent
for epoch in range(epochs):

    # Predictions for entire dataset
    y_pred = m * X + b

    # Compute gradients using ALL samples
    dm = (-2/n) * np.sum(X * (Y - y_pred))
    db = (-2/n) * np.sum(Y - y_pred)

    # Update parameters
    m = m - learning_rate * dm
    b = b - learning_rate * db

    # Calculate loss
    loss = np.mean((Y - y_pred) ** 2)

    # Print every 100 epochs
    if epoch % 100 == 0:
        print(f"Epoch {epoch}, Loss: {loss:.4f}")

print("\nFinal Parameters:")
print("m =", m)
print("b =", b)
# Out:
# Epoch 0, Loss: 30.0000
# Epoch 100, Loss: 0.0341
# Epoch 200, Loss: 0.0187
# Epoch 300, Loss: 0.0103
# Epoch 400, Loss: 0.0056
# Epoch 500, Loss: 0.0031
# Epoch 600, Loss: 0.0017
# Epoch 700, Loss: 0.0009
# Epoch 800, Loss: 0.0005
# Epoch 900, Loss: 0.0003
#
# Final Parameters:
# m = 1.9896587550255742
# b = 0.030404521305361965

# %%
# Final prediction line
y_final = m * X + b

# %%
y_final
# Out:
# array([2.02006328, 4.00972203, 5.99938079, 7.98903954])

# %%
# Plot graph
plt.scatter(X, Y, label="Actual Data")
plt.plot(X, y_final, label="Regression Line")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()
