# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Step 1: Create Dataset
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y = np.array([3, 4, 2, 5, 6])

# %%
# Step 2: Train Model
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Step 3: Predictions
y_pred = model.predict(X)

# %%
# Step 4: Metrics Calculation
mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y, y_pred)

# %%
# Step 5: Print Output
print("Actual values: ", y)
print("Predicted values: ", y_pred)

print("\nMAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2 Score:", r2)
# Out:
# Actual values:  [3 4 2 5 6]
# Predicted values:  [2.6 3.3 4.  4.7 5.4]
#
# MAE: 0.8000000000000004
# MSE: 1.0200000000000002
# RMSE: 1.0099504938362078
# R2 Score: 0.4899999999999999

# %%
# Step 6: Plot Graph
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, y_pred, color='red', label='Regression Line')
plt.title("Example Regression Metrices")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()

# %%
# Step 7: Error Visualization
errors = y - y_pred

plt.bar(range(len(errors)), errors)
plt.title("Error Value")
plt.xlabel("Data Index")
plt.ylabel("Error")
plt.show()
